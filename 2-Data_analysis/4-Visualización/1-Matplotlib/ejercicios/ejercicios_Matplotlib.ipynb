# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
fig = plt.figure()
# Datos para la recta con pendiente positiva (pasa por (0, 0))
x1 = np.linspace(0, 5, 100)
y1 = 3 * x1  # pendiente positiva de 3

# Datos para la recta con pendiente negativa (pasa por (0, -5))
x2 = np.linspace(0, 5, 100)
y2 = -3 * x2 - 5  # pendiente negativa de 3, intersección en (0, -5)

plt.subplot(1, 2, 1)
plt.plot(x1, y1, 1)
plt.subplot(1, 2, 2)
plt.plot(x2, y2, 2);

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
fig = plt.figure()

x1 = np.linspace(0, 5, 100)
y1 = 3 * x1  

x2 = np.linspace(0, 5, 100)
y2 = -3 * x2 - 5  

plt.subplot(1, 2, 1)
plt.plot(x1, y1, 1)
plt.xlim(0, 5)
plt.ylim(-15, 15)

plt.subplot(1, 2, 2)
plt.plot(x2, y2, 2)
plt.xlim(0, 5)
plt.ylim(-15, 15);

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
plt.figure()
x1 = np.linspace(0, 5, 100)
y1 = 3 * x1  

x2 = np.linspace(0, 5, 100)
y2 = -3 * x2 - 5  

plt.subplot(1, 2, 1)
plt.plot(x1,y1)
plt.xlim(0, 5)
plt.ylim(-15, 15)
plt.title('Recta sube')
plt.xlabel('eje X')
plt.ylabel('eje Y')


plt.subplot(1, 2, 2)
plt.plot(x2,y2)
plt.xlim(0, 5)
plt.ylim(-15, 15)
plt.title('Recta baja')
plt.xlabel('eje X');

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
fig, ax = plt.subplots(1,2)

ax[0].plot(x1,y1)
ax[0].set_ylim(-15,15)
ax[0].set_xlim(0,5)
ax[0].set_xlabel('eje X')
ax[0].set_ylabel('eje Y')
ax[0].set_title('Recta sube')

ax[1].plot(x2,y2)
ax[1].set_ylim(-15,15)
ax[1].set_xlim(0,5)
ax[1].set_xlabel('eje X')
ax[1].set_title('Recta baja')
# Out:
# Text(0.5, 1.0, 'Recta baja')

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

plt.bar(x, y, width=1.5, color='skyblue', edgecolor='black')

plt.title("Gráfico de Barras")
plt.xlabel("Coordenadas X")
plt.ylabel("Alturas Y")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
x = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
y = [160, 180, 175, 190, 170]

plt.bar(x, y, width=0.5, color='green', edgecolor='green')

plt.title("Altura de personas")
plt.xlabel("Amigos")
plt.ylabel("Alturas (cm)")
plt.grid(axis='y', linestyle='--', alpha=0.7);

# %%
# Para hacer descendente

x = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
y = [160, 180, 175, 190, 170]
pd = pd.DataFrame(['Alturas': y], index = x).sort_values(['Alturas'], ascending = False)


plt.bar(df.index, df.Alturas, width=0.5, color='green', edgecolor='green')

plt.title("Altura de personas")
plt.xlabel("Amigos")
plt.ylabel("Alturas (cm)")
plt.grid(axis='y', linestyle='--', alpha=0.7);
# Out:
#   Cell In[59], line 5
#     pd = pd.DataFrame(['Alturas': y], index = x).sort_values(['Alturas'], ascending = False)
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
x = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
y = [160, 180, 175, 190, 170]
plt.figure(figsize=(3, 5))

plt.bar(x, y, width=0.5, color='green', edgecolor='green')

plt.title("Altura de personas")
plt.xlabel("Amigos")
plt.ylabel("Alturas (cm)")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
x = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
y = [160, 180, 175, 190, 170]

plt.figure(figsize=(3, 5))

plt.bar(x, y, width=0.5, color='green', edgecolor='green')

plt.title("Altura de personas")
plt.xlabel("Amigos")
plt.ylabel("Alturas (cm)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.yticks([]);

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
x = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
y = [160, 180, 175, 190, 170]
plt.figure(figsize=(5, 3))

plt.barh(x, y, height=0.5, color='green', edgecolor='green')

plt.title("Altura de personas")
plt.xlabel("Altura (cm)")
plt.ylabel("Amigos")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]


fig, ax = plt.subplots(figsize=(5, 3))

ax.barh(nombres, alturas, height=0.5, color='green', edgecolor='green')

ax.invert_yaxis()  
ax.invert_xaxis()  

ax.set_title("Altura de personas")
ax.set_xlabel("Alturas (cm)")
ax.set_ylabel("Amigos")
ax.grid(axis='x', linestyle='--', alpha=0.7)

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

fig, ax = plt.subplots(figsize=(5, 3))

ax.barh(nombres, alturas, height=0.5, color='green', edgecolor='lime')

ax.invert_yaxis()
ax.invert_xaxis()  

ax.set_title("Altura de personas", color='white', pad=20)
ax.set_xlabel("Alturas (cm)", color='lightgray')
ax.set_ylabel("Amigos", color='lightgray')
ax.grid(axis='x', linestyle='--', alpha=0.3, color='gray')

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000]
}

df = pd.DataFrame(data)
df
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.use('seaborn-v0_8-white')

fig, ax = plt.subplots(figsize=(8, 5))


ax.plot(df['Year'], df['Sold_items_A'], 
        color='green', 
        linestyle='--',  
        linewidth=2, 
        marker='o',     
        markersize=8);
        #title='Evaluación de las ventas / año',
        #xlabel='Años',
        #ylabel='ventas')

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000],
    'Sold_items_B': [2000, 3100, 5000, 4000, 6000]
}

df = pd.DataFrame(data)

fig, ax = plt.subplots(figsize=(9, 5))


ax.plot(df['Year'], df['Sold_items_A'], 
        color='green', 
        linestyle='--',  
        linewidth=2, 
        marker='o',     
        markersize=8,
        label='Departamento A')

ax.plot(df['Year'], df['Sold_items_B'], 
        color='red', 
        linestyle=':',  
        linewidth=2, 
        marker='s',     
        markersize=8,
        label='Departamento B')

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
df.plot(x='Year', y='Sold_items_A', kind='scatter', color='green');

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
df.plot(x='Year', y='Sold_items_A', kind='pie', color='green');

# %%
# Otra forma más chula
df.plot(
    y='Sold_items_A',  # Valores para el pie (no usamos x)
    kind='pie',
    labels=df['Year'],  # Etiquetas con los años
    autopct='%1.1f%%',  # Porcentajes con 1 decimal
    colors=['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0'],  # Colores personalizados
    startangle=90,      # Rotación inicial (90° = vertical)
    shadow=True,        # Sombra para efecto 3D
    figsize=(8, 6),     # Tamaño del gráfico
    title='Distribución de Ventas por Año (Departamento A)',
    ylabel=''           # Eliminar etiqueta del eje Y (innecesaria)
);

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
df.plot(
    y='Sold_items_A',
    kind='pie',
    labels=None,  # Eliminamos labels automáticos
    autopct='%1.1f%%', 
    colors=['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0'],
    startangle=90,
    shadow=True,
    figsize=(8, 6),
    title='Distribución de Ventas por Año (Departamento A)',
    legend=False,
    ylabel=''
);

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %%
np.random.seed(42)  # Para reproducibilidad
alturas = np.random.uniform(low=150, high=191, size=300)

df_19 = pd.DataFrame({'alturas': alturas})
plt.figure(figsize=(10, 6))
plt.hist(
    alturas,
    bins=40,  # Número de barras
    color='skyblue',
    edgecolor='navy',
    alpha=0.8,
)
plt.title('Histograma de Alturas')
plt.xlabel('Altura (cm)')
plt.ylabel('Frecuencia');

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
